# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %pip install numpy

# %%
# %unzip "./archive.zip" -d '/content/dataset'
# Out:
# UsageError: Line magic function `%unzip` not found.

# %% [markdown]
# # Exploratory Data Analysis

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, \
    Dropout, Flatten, Dense, Activation, \
    BatchNormalization
from keras import backend as K
from sklearn.model_selection import train_test_split

# %%
# dimensions of our images.
img_width, img_height = 128, 128
img_channels = 3
Image_Size = (img_width, img_height)

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (img_channels, img_width, img_height)
else:
    input_shape = (img_width, img_height, img_channels)

# %%
data_dir = '/content/UTKFace/'

filenames = os.listdir(data_dir)
ages = []
genders = []
for file_name in filenames:
    age = file_name.split("_")[0]
    ages.append(int(age))

    gender = file_name.split("_")[1]
    if gender == '0':
        genders.append("male")
    else:
        genders.append('female')

df = pd.DataFrame({
    'filename': filenames,
    'age': ages,
    'gender': genders
})

# %%
df.head()
# Out:
#                                 filename  age  gender
# 0  32_1_1_20170113001556123.jpg.chip.jpg   32  female
# 1  26_1_0_20170103235707476.jpg.chip.jpg   26  female
# 2  20_0_1_20170116204110339.jpg.chip.jpg   20    male
# 3  60_1_0_20170110153047755.jpg.chip.jpg   60  female
# 4  35_0_0_20170117190418977.jpg.chip.jpg   35    male

# %%
# histogram of df
df['age'].hist(bins=117, figsize=(20, 10), xrot=90)

# %%
# histogram of df
df['gender'].hist()

# %%
# looking data
sample = np.random.randint(len(df))

img_path = data_dir + df['filename'][sample]
age = df['age'][sample]
gender = df['gender'][sample]

img = Image.open(img_path)

plt.imshow(img)
plt.title(f"Class: {age}-{gender}")
plt.axis('off')
plt.show()

# %% [markdown]
# # Training Model

# %%
data_dir = '/content/UTKFace/'

filenames = os.listdir(data_dir)
ages = []
genders = []
for file_name in filenames:
    age = file_name.split("_")[0]
    ages.append(int(age))

    gender = file_name.split("_")[1]
    genders.append(int(gender))

df = pd.DataFrame({
    'filename': filenames,
    'age': ages,
    'gender': genders
})

df
# Out:
#                                     filename  age  gender
# 0      32_1_1_20170113001556123.jpg.chip.jpg   32       1
# 1      26_1_0_20170103235707476.jpg.chip.jpg   26       1
# 2      20_0_1_20170116204110339.jpg.chip.jpg   20       0
# 3      60_1_0_20170110153047755.jpg.chip.jpg   60       1
# 4      35_0_0_20170117190418977.jpg.chip.jpg   35       0
# ...                                      ...  ...     ...
# 23703  71_1_0_20170110181315747.jpg.chip.jpg   71       1
# 23704  35_0_1_20170117164220595.jpg.chip.jpg   35       0
# 23705   3_0_1_20170110213755346.jpg.chip.jpg    3       0
# 23706  28_1_2_20170116164200987.jpg.chip.jpg   28       1
# 23707   1_1_2_20161219205821918.jpg.chip.jpg    1       1
#
# [23708 rows x 3 columns]

# %%
from tqdm import tqdm
from PIL import Image, ImageOps

def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(data_dir + image, grayscale=False)
        img = img.resize((64, 64), Image.ANTIALIAS)
        img = np.array(img)
        features.append(img)
        
    features = np.array(features)
    # ignore this step if using RGB
    #features = features.reshape(len(features), 128, 128, 3)
    return features

# %%
X = extract_features(df['filename'])
# Out:
# 100%|██████████| 23708/23708 [00:32<00:00, 740.47it/s]

# %%
# Normalize the images
X = X / 255.0

# %%
y_gender = np.array(df['gender'])
y_age = np.array(df['age'])

# %%
from tensorflow.keras import Input, Model

input_shape = (64, 64, 3)

inputs = Input((input_shape))
# convolutional layers
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu') (inputs)
maxp_1 = MaxPooling2D(pool_size=(2, 2)) (conv_1)
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu') (maxp_1)
maxp_2 = MaxPooling2D(pool_size=(2, 2)) (conv_2)
conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu') (maxp_2)
maxp_3 = MaxPooling2D(pool_size=(2, 2)) (conv_3)
conv_4 = Conv2D(128, kernel_size=(3, 3), activation='relu') (maxp_3)
maxp_4 = MaxPooling2D(pool_size=(2, 2)) (conv_4)

flatten_age = Flatten() (maxp_4)
flatten_gender = Flatten() (maxp_3)

# fully connected layers
dense_1 = Dense(128, activation='relu') (flatten_gender)
dense_2 = Dense(128, activation='relu') (flatten_age)

dropout_1 = Dropout(0.3) (dense_1)
dropout_2 = Dropout(0.3) (dense_2)

output_1 = Dense(1, activation='sigmoid', name='gender_out') (dropout_1)
output_2 = Dense(1, activation='relu', name='age_out') (dropout_2)

model = Model(inputs=[inputs], outputs=[output_1, output_2])

model.compile(loss=['binary_crossentropy', 'mae'], optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 62, 62, 32)   896         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 31, 31, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 29, 29, 64)   18496       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 64)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 12, 12, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 128)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 4, 4, 128)    147584      ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 128)   0           ['conv2d_3[0][0]']
#
#  flatten_1 (Flatten)            (None, 4608)         0           ['max_pooling2d_2[0][0]']
#
#  flatten (Flatten)              (None, 512)          0           ['max_pooling2d_3[0][0]']
#
#  dense (Dense)                  (None, 128)          589952      ['flatten_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          65664       ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_1[0][0]']
#
#  gender_out (Dense)             (None, 1)            129         ['dropout[0][0]']
#
#  age_out (Dense)                (None, 1)            129         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 896,706
# Trainable params: 896,706
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
#Train model
history = model.fit(x=X, y=[y_gender, y_age], batch_size=32, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 593/593 [==============================] - 8s 10ms/step - loss: 16.4849 - gender_out_loss: 0.6795 - age_out_loss: 15.8054 - gender_out_accuracy: 0.5728 - age_out_accuracy: 0.0464 - val_loss: 14.8005 - val_gender_out_loss: 0.6269 - val_age_out_loss: 14.1736 - val_gender_out_accuracy: 0.7003 - val_age_out_accuracy: 0.0508
# Epoch 2/30
# 593/593 [==============================] - 5s 9ms/step - loss: 12.3468 - gender_out_loss: 0.5371 - age_out_loss: 11.8097 - gender_out_accuracy: 0.7346 - age_out_accuracy: 0.0383 - val_loss: 10.7471 - val_gender_out_loss: 0.4342 - val_age_out_loss: 10.3129 - val_gender_out_accuracy: 0.7927 - val_age_out_accuracy: 0.0209
# Epoch 3/30
# 593/593 [==============================] - 6s 9ms/step - loss: 10.4321 - gender_out_loss: 0.4467 - age_out_loss: 9.9854 - gender_out_accuracy: 0.7827 - age_out_accuracy: 0.0325 - val_loss: 9.8773 - val_gender_out_loss: 0.3830 - val_age_out_loss: 9.4944 - val_gender_out_accuracy: 0.8186 - val_age_out_accuracy: 0.0500
# Epoch 4/30
# 593/593 [==============================] - 6s 9ms/step - loss: 9.5486 - gender_out_loss: 0.3980 - age_out_loss: 9.1505 - gender_out_accuracy: 0.8068 - age_out_accuracy: 0.0376 - val_loss: 8.7118 - val_gender_out_loss: 0.3413 - val_age_out_loss: 8.3704 - val_gender_out_accuracy: 0.8372 - val_age_out_accuracy: 0.0508
# Epoch 5/30
# 593/593 [==============================] - 6s 9ms/step - loss: 8.9460 - gender_out_loss: 0.3654 - age_out_loss: 8.5805 - gender_out_accuracy: 0.8255 - age_out_accuracy: 0.0432 - val_loss: 8.3737 - val_gender_out_loss: 0.3398 - val_age_out_loss: 8.0339 - val_gender_out_accuracy: 0.8494 - val_age_out_accuracy: 0.0504
# Epoch 6/30
# 593/593 [==============================] - 5s 9ms/step - loss: 8.4786 - gender_out_loss: 0.3402 - age_out_loss: 8.1383 - gender_out_accuracy: 0.8430 - age_out_accuracy: 0.0449 - val_loss: 8.7505 - val_gender_out_loss: 0.3240 - val_age_out_loss: 8.4265 - val_gender_out_accuracy: 0.8528 - val_age_out_accuracy: 0.0508
# Epoch 7/30
# 593/593 [==============================] - 5s 9ms/step - loss: 8.2206 - gender_out_loss: 0.3271 - age_out_loss: 7.8935 - gender_out_accuracy: 0.8516 - age_out_accuracy: 0.0460 - val_loss: 7.6993 - val_gender_out_loss: 0.3070 - val_age_out_loss: 7.3923 - val_gender_out_accuracy: 0.8606 - val_age_out_accuracy: 0.0508
# Epoch 8/30
# 593/593 [==============================] - 5s 9ms/step - loss: 7.8719 - gender_out_loss: 0.3148 - age_out_loss: 7.5571 - gender_out_accuracy: 0.8571 - age_out_accuracy: 0.0462 - val_loss: 8.0207 - val_gender_out_loss: 0.2890 - val_age_out_loss: 7.7317 - val_gender_out_accuracy: 0.8766 - val_age_out_accuracy: 0.0508
# Epoch 9/30
# 593/593 [==============================] - 5s 9ms/step - loss: 7.7314 - gender_out_loss: 0.3074 - age_out_loss: 7.4240 - gender_out_accuracy: 0.8614 - age_out_accuracy: 0.0465 - val_loss: 7.3456 - val_gender_out_loss: 0.2942 - val_age_out_loss: 7.0514 - val_gender_out_accuracy: 0.8621 - val_age_out_accuracy: 0.0508
# Epoch 10/30
# 593/593 [==============================] - 5s 9ms/step - loss: 7.4425 - gender_out_loss: 0.2964 - age_out_loss: 7.1461 - gender_out_accuracy: 0.8614 - age_out_accuracy: 0.0464 - val_loss: 7.3094 - val_gender_out_loss: 0.2796 - val_age_out_loss: 7.0298 - val_gender_out_accuracy: 0.8745 - val_age_out_accuracy: 0.0508
# Epoch 11/30
# 593/593 [==============================] - 5s 9ms/step - loss: 7.2720 - gender_out_loss: 0.2929 - age_out_loss: 6.9791 - gender_out_accuracy: 0.8659 - age_out_accuracy: 0.0465 - val_loss: 7.4359 - val_gender_out_loss: 0.3128 - val_age_out_loss: 7.1231 - val_gender_out_accuracy: 0.8458 - val_age_out_accuracy: 0.0508
# Epoch 12/30
# 593/593 [==============================] - 5s 9ms/step - loss: 7.0577 - gender_out_loss: 0.2810 - age_out_loss: 6.7766 - gender_out_accuracy: 0.8735 - age_out_accuracy: 0.0465 - val_loss: 7.1159 - val_gender_out_loss: 0.2715 - val_age_out_loss: 6.8445 - val_gender_out_accuracy: 0.8798 - val_age_out_accuracy: 0.0508
# Epoch 13/30
# 593/593 [==============================] - 5s 9ms/step - loss: 7.0297 - gender_out_loss: 0.2754 - age_out_loss: 6.7543 - gender_out_accuracy: 0.8761 - age_out_accuracy: 0.0465 - val_loss: 7.3687 - val_gender_out_loss: 0.2699 - val_age_out_loss: 7.0989 - val_gender_out_accuracy: 0.8802 - val_age_out_accuracy: 0.0508
# Epoch 14/30
# 593/593 [==============================] - 6s 9ms/step - loss: 6.7982 - gender_out_loss: 0.2657 - age_out_loss: 6.5325 - gender_out_accuracy: 0.8798 - age_out_accuracy: 0.0465 - val_loss: 7.5429 - val_gender_out_loss: 0.2639 - val_age_out_loss: 7.2791 - val_gender_out_accuracy: 0.8834 - val_age_out_accuracy: 0.0508
# Epoch 15/30
# 593/593 [==============================] - 6s 9ms/step - loss: 6.6091 - gender_out_loss: 0.2604 - age_out_loss: 6.3487 - gender_out_accuracy: 0.8828 - age_out_accuracy: 0.0465 - val_loss: 7.0504 - val_gender_out_loss: 0.2725 - val_age_out_loss: 6.7779 - val_gender_out_accuracy: 0.8815 - val_age_out_accuracy: 0.0508
# Epoch 16/30
# 593/593 [==============================] - 5s 9ms/step - loss: 6.4281 - gender_out_loss: 0.2568 - age_out_loss: 6.1713 - gender_out_accuracy: 0.8875 - age_out_accuracy: 0.0465 - val_loss: 7.8017 - val_gender_out_loss: 0.2795 - val_age_out_loss: 7.5222 - val_gender_out_accuracy: 0.8739 - val_age_out_accuracy: 0.0508
# Epoch 17/30
# 593/593 [==============================] - 5s 9ms/step - loss: 6.3414 - gender_out_loss: 0.2495 - age_out_loss: 6.0920 - gender_out_accuracy: 0.8906 - age_out_accuracy: 0.0465 - val_loss: 7.0698 - val_gender_out_loss: 0.2622 - val_age_out_loss: 6.8076 - val_gender_out_accuracy: 0.8876 - val_age_out_accuracy: 0.0508
# Epoch 18/30
# 593/593 [==============================] - 8s 13ms/step - loss: 6.2111 - gender_out_loss: 0.2423 - age_out_loss: 5.9688 - gender_out_accuracy: 0.8940 - age_out_accuracy: 0.0465 - val_loss: 7.2748 - val_gender_out_loss: 0.2596 - val_age_out_loss: 7.0152 - val_gender_out_accuracy: 0.8884 - val_age_out_accuracy: 0.0508
# Epoch 19/30
# 593/593 [==============================] - 6s 9ms/step - loss: 6.2044 - gender_out_loss: 0.2356 - age_out_loss: 5.9689 - gender_out_accuracy: 0.8931 - age_out_accuracy: 0.0465 - val_loss: 6.8828 - val_gender_out_loss: 0.2743 - val_age_out_loss: 6.6084 - val_gender_out_accuracy: 0.8817 - val_age_out_accuracy: 0.0508
# Epoch 20/30
# 593/593 [==============================] - 5s 9ms/step - loss: 6.0514 - gender_out_loss: 0.2312 - age_out_loss: 5.8203 - gender_out_accuracy: 0.8968 - age_out_accuracy: 0.0465 - val_loss: 7.3585 - val_gender_out_loss: 0.2696 - val_age_out_loss: 7.0889 - val_gender_out_accuracy: 0.8897 - val_age_out_accuracy: 0.0508
# Epoch 21/30
# 593/593 [==============================] - 6s 9ms/step - loss: 5.8947 - gender_out_loss: 0.2277 - age_out_loss: 5.6670 - gender_out_accuracy: 0.8961 - age_out_accuracy: 0.0465 - val_loss: 6.8432 - val_gender_out_loss: 0.2623 - val_age_out_loss: 6.5810 - val_gender_out_accuracy: 0.8912 - val_age_out_accuracy: 0.0508
# Epoch 22/30
# 593/593 [==============================] - 5s 9ms/step - loss: 5.8976 - gender_out_loss: 0.2255 - age_out_loss: 5.6721 - gender_out_accuracy: 0.8976 - age_out_accuracy: 0.0465 - val_loss: 6.9779 - val_gender_out_loss: 0.2687 - val_age_out_loss: 6.7092 - val_gender_out_accuracy: 0.8920 - val_age_out_accuracy: 0.0508
# Epoch 23/30
# 593/593 [==============================] - 5s 9ms/step - loss: 5.7301 - gender_out_loss: 0.2225 - age_out_loss: 5.5076 - gender_out_accuracy: 0.8977 - age_out_accuracy: 0.0465 - val_loss: 7.3150 - val_gender_out_loss: 0.2622 - val_age_out_loss: 7.0528 - val_gender_out_accuracy: 0.8960 - val_age_out_accuracy: 0.0508
# Epoch 24/30
# 593/593 [==============================] - 5s 9ms/step - loss: 5.6896 - gender_out_loss: 0.2167 - age_out_loss: 5.4729 - gender_out_accuracy: 0.9000 - age_out_accuracy: 0.0465 - val_loss: 7.0893 - val_gender_out_loss: 0.2602 - val_age_out_loss: 6.8290 - val_gender_out_accuracy: 0.8943 - val_age_out_accuracy: 0.0508
# Epoch 25/30
# 593/593 [==============================] - 6s 9ms/step - loss: 5.5940 - gender_out_loss: 0.2162 - age_out_loss: 5.3778 - gender_out_accuracy: 0.9028 - age_out_accuracy: 0.0465 - val_loss: 6.8879 - val_gender_out_loss: 0.2791 - val_age_out_loss: 6.6088 - val_gender_out_accuracy: 0.8939 - val_age_out_accuracy: 0.0508
# Epoch 26/30
# 593/593 [==============================] - 5s 9ms/step - loss: 5.4990 - gender_out_loss: 0.2119 - age_out_loss: 5.2871 - gender_out_accuracy: 0.9030 - age_out_accuracy: 0.0464 - val_loss: 7.3774 - val_gender_out_loss: 0.2839 - val_age_out_loss: 7.0935 - val_gender_out_accuracy: 0.8910 - val_age_out_accuracy: 0.0508
# Epoch 27/30
# 593/593 [==============================] - 5s 9ms/step - loss: 5.3817 - gender_out_loss: 0.2069 - age_out_loss: 5.1748 - gender_out_accuracy: 0.9048 - age_out_accuracy: 0.0465 - val_loss: 7.1119 - val_gender_out_loss: 0.2690 - val_age_out_loss: 6.8429 - val_gender_out_accuracy: 0.8916 - val_age_out_accuracy: 0.0508
# Epoch 28/30
# 593/593 [==============================] - 5s 9ms/step - loss: 5.3025 - gender_out_loss: 0.2048 - age_out_loss: 5.0977 - gender_out_accuracy: 0.9051 - age_out_accuracy: 0.0463 - val_loss: 7.6043 - val_gender_out_loss: 0.2789 - val_age_out_loss: 7.3254 - val_gender_out_accuracy: 0.8918 - val_age_out_accuracy: 0.0508
# Epoch 29/30
# 593/593 [==============================] - 6s 9ms/step - loss: 5.3488 - gender_out_loss: 0.2027 - age_out_loss: 5.1461 - gender_out_accuracy: 0.9046 - age_out_accuracy: 0.0462 - val_loss: 7.0449 - val_gender_out_loss: 0.2678 - val_age_out_loss: 6.7771 - val_gender_out_accuracy: 0.8895 - val_age_out_accuracy: 0.0508
# Epoch 30/30
# 593/593 [==============================] - 6s 9ms/step - loss: 5.1888 - gender_out_loss: 0.1988 - age_out_loss: 4.9900 - gender_out_accuracy: 0.9085 - age_out_accuracy: 0.0463 - val_loss: 6.9016 - val_gender_out_loss: 0.2784 - val_age_out_loss: 6.6232 - val_gender_out_accuracy: 0.8903 - val_age_out_accuracy: 0.0508

# %%
# plot results for gender
acc = history.history['gender_out_accuracy']
val_acc = history.history['val_gender_out_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()

loss = history.history['gender_out_loss']
val_loss = history.history['val_gender_out_loss']

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
#Plot results for age
acc = history.history['age_out_accuracy']
val_acc = history.history['val_age_out_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()


loss = history.history['age_out_loss']
val_loss = history.history['val_age_out_loss']
epochs = range(len(loss))

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
model.save("checkpoints/model.h5")

# %%
image_index = 1
gender_dict = {0:'Male', 1:'Female'}

# predict from model
pred = model.predict(X[image_index].reshape(1, 64, 64, 3))
pred_gender = gender_dict[round(pred[0][0][0])]
pred_age = round(pred[1][0][0])
print(f"Original Gender: {gender_dict[y_gender[image_index]]}, Original Age: {y_age[image_index]}")
print(f"Predicted Gender: {pred_gender}, Predicted Age: {pred_age}")
plt.axis('off')
plt.imshow(X[image_index]);
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Original Gender: Female, Original Age: 26
# Predicted Gender: Female, Predicted Age: 25

# %% [markdown]
# -------------------------------------------------------------------------------✈

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/Hust/Age-Gender-Prediction"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Hust/Age-Gender-Prediction

# %%
import os

import tensorflow as tf
from tensorflow import keras

from PIL import Image, ImageOps
from tensorflow.keras.preprocessing.image import load_img
import numpy as np
import matplotlib.pyplot as plt

model = tf.keras.models.load_model("checkpoints/model.h5")
# %cd "./testimg"

# %%
# %ls
# Out:
# hermione.png  mixi.png  phuong0.png  phuong1.png  thuytien.png

# %%
def testimg(path): 
    img = load_img(path, grayscale=False)
    img = img.resize((64, 64), Image.ANTIALIAS)
    img = np.array(img)
    gender_dict = {0:'Male', 1:'Female'}

    # predict from model
    pred = model.predict(img.reshape(1, 64, 64, 3))
    pred_gender = gender_dict[round(pred[0][0][0])]
    pred_age = round(pred[1][0][0]/100)

    print(f"Predicted Gender: {pred_gender}, Predicted Age: {(pred_age)}")
    plt.axis('off')
    plt.imshow(img)
    plt.show()
    return

# %%
# testimg("phuong0.png")
# testimg("phuong1.png")
testimg("mixi.png")
testimg("thuytien.png")
testimg("nguoiyeucu.png")
testimg("evans.png")
testimg("littlegirl.png")
# Out:
# 1/1 [==============================] - 0s 24ms/step
# Predicted Gender: Male, Predicted Age: 32
# 1/1 [==============================] - 0s 38ms/step
# Predicted Gender: Female, Predicted Age: 36
# 1/1 [==============================] - 0s 28ms/step
# Predicted Gender: Female, Predicted Age: 15
# 1/1 [==============================] - 0s 66ms/step
# Predicted Gender: Male, Predicted Age: 22
# 1/1 [==============================] - 0s 68ms/step
# Predicted Gender: Male, Predicted Age: 35
